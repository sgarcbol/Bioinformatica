# %% [markdown]
# # PRIMER NOTEBOOK

# %% [markdown]
# #### Este es mi primer notebook y voy a hacer lo siguiente

# %% [markdown]
#  Una lista enumerada:
# 1. Primero
# 2. Segundo
# 3. Tercero

# %% [markdown]
# Una lista por puntos:
# - Primero
# -  Segundo
# - Tercero

# %% [markdown]
# Mi primer código:

# %%
mi_primera_frase = "Hello world"

# %%
# Como cuando lo ejecuto no sale nada, tengo que usar la función print () 
print(mi_primera_frase)
# Out:
# Hello world

# %%
# A ver si así lo entiendes mejor: 
numeros = (10,20,30,40,50)

# %%
media = sum(numeros) /len(numeros)

# %%
print(media)
# Out:
# 30.0

# %% [markdown]
# #### Finalizamos con una bonita imagen

# %% [markdown]
# ![delfin](https://www.mundomar.es/wp-content/uploads/2017/09/dolphin-1019616_1920.jpg)
